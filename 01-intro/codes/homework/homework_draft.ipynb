# %%
import pandas as pd
# Out:
# c:\anaconda\lib\site-packages\pandas\core\arrays\masked.py:62: UserWarning: Pandas requires version '1.3.4' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv
# Out:
# 'wget' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
x=pd.read_csv('car_fuel_efficiency.csv')

# %%
x.__len__()
# Out:
# 9704

# %%
x.isnull().any()
# Out:
# engine_displacement    False
# num_cylinders           True
# horsepower              True
# vehicle_weight         False
# acceleration            True
# model_year             False
# origin                 False
# fuel_type              False
# drivetrain             False
# num_doors               True
# fuel_efficiency_mpg    False
# dtype: bool

# %%
x[x['origin']=="Asia"]["fuel_efficiency_mpg"].max()
# Out:
# 23.759122836520497

# %%
x.horsepower.median()
# Out:
# 152.0

# %%
most_frequent_number = x.horsepower.mode()

# %%
most_frequent_number[0]
# Out:
# 152.0

# %%
number_statistics = x.horsepower.value_counts()

# %%
x.horsepower.value_counts()

# %%
x['horsepower'] = x['horsepower'].fillna(x['horsepower'].mode()[0])

# %%
X=x[x['origin']=="Asia"][['vehicle_weight','model_year']].head(7).values

# %%
import numpy as np
XTX=X.T.dot(X)

# %%
XTX
# Out:
# array([[62248334.33150762, 41431216.5073268 ],
#        [41431216.5073268 , 28373339.        ]])

# %%
Vs_inv = np.linalg.inv(XTX)

# %%
Vs_inv
# Out:
# array([[ 5.71497081e-07, -8.34509443e-07],
#        [-8.34509443e-07,  1.25380877e-06]])

# %%
y = [1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
sum(Vs_inv.dot(X.T).dot(y))
# Out:
# 0.5187709081074016
